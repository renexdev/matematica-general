# %% [markdown]
# <h1>Matemática General - 2019</h1>
# <h2>Universidad del Comahue. Centro Regional Bariloche</h2>
#
# <h2>Profesorado y Licenciatura en Matematica</h2>
#
# http://crubweb.uncoma.edu.ar/
#
# M. Juan, N.R. Cejas Bolecek
#
# El presente material constituye solo una guía de algunos de los contenidos desarrollados en la teoría de la Unidad 4. Para preparar el examen final de la materia se deben profundizar los temas aquí desarrollados con la bibliografía sugerida en el programa de la materia.
#
# Contacto: rene.bolecek@gmail.com
#
# Revisión: v. 0.1

# %% [markdown]
# <h2>Funciones con Dominio Real</h2>
# <h3>Introducción</h3>
#
# En matemática, una función es una $\textbf{regla}$ que asigna a cada elemento de un conjunto $D$ de salida un elemento de otro conjunto $E$ de llegada (que puede coincidir con el primer conjunto).
#
# <center>
# <div style="width: 200px;" >
# <img src="img/arrow-diagram.jpg">
# </center>
# </div>
#
# Trataremos con funciones que a cada número real de un cierto conjunto prefijado, le corresponde otro número real. Tales funciones se denominan funciones de variable real y a valores reales.
#
# Retomemos la definición de función [2]
#
#
#  > $f$ es una función o aplicación de D=$\mathbb{R}$ en E=$\mathbb{R}$, $f$ : $\mathbb{R} \rightarrow \mathbb{R}$, sii $f$ es una relación entre D y E, tal que todo elemento de D tiene un único correspondiente en E.
#
# o expresado matemáticamente:
#  > $f$ es una función de D=$\mathbb{R}$ en $E=\mathbb{R}$ sii $f$ es un subconjunto de DxE que satisface:
#
# > i) $\forall x \in\mathbb{R}$, $\exists y\in\mathbb{R}$/ $(x,y) \in\, f$ (Existencia)
#
# > ii) $(x,y) \in\, f \land$ $(x,z) \in\, f \Rightarrow y=z$ (Unicidad)
#
# El $\textbf{dominio}$ de la función $f$ es la totalidad de los elementos del conjunto de salida ($\mathbb{R}$) que admiten imagen en el conjunto de llegada ($\mathbb{R}$)
#
# > $Dom(f)$ = {x $\in \mathbb{R} / (x,y) \in f(x)$}
#
# Notar: cuando tenemos una fórmula para definir la función, el dominio se define como aquellos números reales para los cuales “podemos hacer la cuenta”. Algunas operaciones tienen sus restricciones:
#
# >* Un denominador no puede ser cero
#
# >* Una raíz cuadrada no puede calcularse sobre números negativos
#
# >* Algunas funciones como el logaritmo no pueden calcularse sobre números negativos ni sobre cero (ya lo veremos en detalle más adelante)
#
#
# Definimos la $\textbf{imagen}$ (codominio o rango) de una función $f$ como el conjunto de los elementos del conjunto de llegada ($\mathbb{R}$) que admiten un antecedente en el conjunto de salida($\mathbb{R}$)
#
# > $Im(f)$ = {y $\in \mathbb{R} / \exists x \in  Dom(f), y=f(x)$}
#
# Notar que una función queda especificada si se dan el dominio (o conjunto de salida), el codominio (conjunto de llegada) y además la relación f$\subset\mathbb{R}x\mathbb{R}$, que satisface las condiciones i) y ii) de la definición.

# %% [markdown]
# $\textbf{Ejemplo 1.}$ Escribir la regla que a cada número real se le asigna su duplo
#
# f(x)=2x
#
# $\textbf{Ejemplo 2.}$  Escribir la regla que a cada número real se le asigna su cuadrado
#
# g(x)=x$^2$
#
# $\textbf{Ejemplo 3.}$  Sea $h(x)=\sqrt{x-1}$
#
#
# Nos dice que a cada número real se le asigna la raíz cuadrada del número real menos uno.
#
# Nos queda especificar cuáles son los dominios y las imágenes de los ejemplos 1 al 3 para definir en forma unívoca la función.
#
# En los ejemplos $\textbf{(1)}$ y $\textbf{(2)}$ podemos demostrar que Dom(f) y Dom(g) son los $\mathbb{R}$. No existe ningún $x$ tal que $f$ y $g$ no estén definidos!
#
# En el ejemplo  $\textbf{3}$ debemos observar que la función $\sqrt{u} \in \mathbb{R}$ si $u\geqslant0$, caso contrario $\sqrt{u} \notin \mathbb{R}$. Por lo tanto debe ser $x-1\geqslant0$, es decir $x\geqslant1$. En consecuencia, el Dom(g)=[1,$\infty$)
#
# Las imágenes de las funciones anteriores estan dadas por:
#
# Para el Ej. $\textbf{1.}$  $Im(f)=\mathbb{R}$, es fácil ver que para cualquier $y \in \mathbb{R}$  existe $x=y/2\in \mathbb{R}$ tal que y = 2y/2.
#
# Para el Ej. $\textbf{2.}$  $Im(g)=[0,\infty$), pues el cuadrado de cualquier número $\mathbb{R}$ es un número no negativo.
#
# Para el Ej. $\textbf{3.}$  No es tan directo en este caso, dado $y \in \mathbb{R}$ queremos determinar si existe un $x \in \mathbb{R}$ tal que y=h(x). Lo que debemos hacer es despejar $x$ de la ecuación $y=\sqrt{x-1}$ **(1)**, quedando $x = y^2+1$ por lo que concluimos que dando cualquier $y\geqslant0$, existe un $x \in \mathbb{R}$ que verifica la ecuación **(1)**.

# %% [markdown]
# Notar: La letra $x$ en todos los casos es una variable, representa un número real no especificado. A la variable $x$ se la llama variable independiente y a $y$ se la llama variable dependiente.
#
# Una forma muy conveniente de visualizar funciones es a través de su gráfica. Si f es una función con dominio D (en nuestro caso los  $\mathbb{R}$), entonces su gráfica es el conjunto de pares ordenados: $\{(x,f(x)/x \in D)\}$. Veremos más adelante que la gráfica nos da un panorama global del comportamiento de la función.
#
# <center>
# <div style="width: 600px;" >
# <img src="img/function-plot.jpg">
# </center>
# </div>
#
# Notar que la representación gráfica del dominio de una función es en la recta real, sobre el eje x, mientras que el codominio de una función en la recta real queda determinado sobre el eje y. Cuando se hace una gráfica para representar un función $\textbf{siempre}$ se deben colocar los nombres de las variables en cada eje!

# %% [markdown]
# <h3>Funciones definidas por partes</h3>
#
# En los ejemplos dados hemos estudiado funciones definidas por una fórmula, pero las funciones también pueden estar definidas por varias fórmulas.
#
# $\textbf{Ejemplo 4.}$ Graficar la función $f$ : $\mathbb{R} \rightarrow \mathbb{R}$  definada por
#
# $$f(x) = \left\{ \begin{array}{ll} x^2 \quad x \leq 1 \\ 2x+1 \quad x > 1 \end{array} \right.$$
#
# **Tarea.** Grafique las siguiente funciones $f$ : $\mathbb{R} \rightarrow \mathbb{R}$:
# * Función valor absoluto definada por
#
# $$|\,x\,| = \left\{ \begin{array}{ll} x \quad x \geq 0 \\ -x \quad x \leq 0 \end{array} \right.$$
#
# * Función máximo entero $[|x|]$ = el entero más grande menor o igual a x. Ayuda, considere por ejemplo los siguiente valores: $[|2|]=2$, $[|2.3|]=2$, $[|1.999|]=1$, $[|0.002|]=0$, $[|-3.5|]=-4$, $[|-0.5|]=-1$

# %%
# %matplotlib inline
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

plt.figure()
#Eje horizontal
plt.axhline(0, color='black')
#Eje vertical
plt.axvline(0, color='black')
#Grafico la funcion por partes
x1 = np.linspace(-6, 1, 50)
x2 = np.linspace(1.1, 6, 50)
plt.plot(x1,x1**2, 'b', lw= 2, label='$x^2\, , \, x\leq 1$')
plt.plot(x2,2*x2+1, 'r',lw= 2,  label='$2x+1\, , \, x>1$')
#Puntos en el límite del intervalo
plt.scatter([1],[1], lw= 2, s=50, edgecolor='b')
plt.scatter([1],[3], lw= 2, s=50, c='white',facecolor='white', edgecolor='red')

#Establezco limites para graficar
plt.xlim(-6, 6)
plt.ylim(-5, 16)
#Titulo y nombre a los ejes
plt.title("Ejemplo 4")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Volvamos a los ejemplos 1) y 2) para estudiar más en detalle lo que se conoce como funciones lineales y cuadráticas.
#
# <h3>Breve Repaso de conceptos...</h3>
#
# <h2>Funciones lineales</h2>
#
#  > Una función lineal es una función $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ de la forma $f(x)=ax+b$ **(2)**. El parámetro $a$ se denomina pendiente y el parámetro $b$ ordenada al origen.
#
# Ejercicio. Identificar cual de los ejemplos es lineal y dar el valor de $a$ y $b$.
#
# $\textbf{Ejemplo 5}$. Sea $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ definida por $f(x)=3x+2$
#
# (a) Realizar la tabla de valores y graficar la función
#
# (b) Calcular la pendiente de $f$
#
# $\textbf{¿Qué cosas se espera que puedas hacer?}$
#
# * Graficar una recta reconociendo su ordenada al origen y el signo y magnitud de su pendiente
#
# * Encontrar los puntos de intersección de la recta con ambos ejes coordenados
#
# * Encontrar la ecuación de una recta que pasa por dos puntos
#
# * Encontrar la ecuación de una recta que pasa por un punto y tiene una pendiente conocida
#
# * Despejar x de una ecuación lineal
#
# * Plantear y resolver problemas donde estén involucradas funciones y ecuaciones lineales
#
# * Resolver inecuaciones (desigualdades) lineales, gráfica o analíticamente
#
# * Reconocer en el gráfico de la función el conjunto de valores del dominio donde la función es positiva y donde es negativa

# %%
# %matplotlib inline
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-6, 6, 50)
def lineal(a,b,x):
    return a*x+b

def signo(x):
    if x > 0: return "+"
    if x < 0: return "-"
    
def label(a,b):
    if a==0. and b==0.: return "$f(x) = 0$"
    if a==0. and b!=0.: return "$f(x) = %s%s$"%(signo(b),abs(b))
    if a!=0. and b==0.: return "$f(x) = %s%sx$"%(signo(a),abs(a))
    if a!=0. and b!=0.: return "$f(x) = %s%sx %s%s$"%(signo(a),abs(a),signo(b),abs(b))

    
fig, ax = plt.subplots(nrows=3, ncols=5)
plt.tight_layout()
l1 = 5.
l2 = l1*.5
plt.subplots_adjust(left=l2, bottom=l2, right=l1, top=l1, wspace=.1, hspace=None)
plt.title("Ejemplo 5")

a = -1
b = -5
for row in ax:
    for col in row:
        col.plot(x, [lineal(a,b,x) for x in x ],lw=2,c='red',label=label(a,b))
        col.legend(loc='best', shadow=True)
        col.axhline(0, color='black')
        col.axvline(0, color='black')
        col.set_xlim(-6.,6.)
        col.set_ylim(-10.,10.)
        col.set_xlabel("x")
        col.set_ylabel("y")
        #print(a,' ',b)
        a=a+0.5
    a=-1
    b=b+5.
plt.show()

# %% [markdown]
# <h2>Funciones cuadráticas</h2>
# > Una función cuadrática $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ es una función de la forma $f(x)=ax²+bx+c$ **(3)** con $a\neq 0$.
#
# La forma estándar de la función cuadrática se escribe como $f(x)=a(x-h)^2+k$ **(4)**, siendo $(h,k)$ el vértice de la parábola y el parámetro $a$ la apertura. La ecuación se obtiene completando cuadrados en **(3)**
#
# <center>
# <div style="width: 600px;" >
# <img src="img/parabola.jpg">
# </center>
# </div>
#
# **Tarea.** Escriba los parámetros $a,h,k$ como función de $a,b,c$ a partir de las ecuaciones **(3)** y **(4)**.
#
#
# $\textbf{¿Qué cosas se espera que puedas hacer?}$
#
# * Graficar una parábola a partir de la forma estandar.
#
# * Determinar los puntos de intersección de la curva con ambos ejes coordenados
#
# * Determinar la ecuación de una parábola conocidas las raíces y otro punto.
#
# * Determinar la ecuación de una parábola conocidos tres puntos por los que pasa.
#
# * Factorear una expresión polinómica de grado 2 (casos factor común, diferencia de cuadrados ó buscando sus raíces)
#
# * Plantear y resolver problemas donde estén involucradas funciones y ecuaciones cuadráticas.
#
# * Resolver inecuaciones (desigualdades) de segundo grado, gráfica o analíticamente.
#
# * Reconocer en el gráfico de la función el conjunto de valores del dominio donde la función es positiva y donde es negativa

# %% [markdown]
# <h2>Generalidades de las funciones</h2>
#
# ** Funciones implícitas y explícitas**
#
# Las dos variables (dependiente e independiente) pueden venir dadas por la expresión $y=f(x)$, como se vio en los ejemplos: 1) $y=2x$, 2) $y=x^2$. Cuando está dada en esta forma se dice que está en la **forma explícita**. Sin embargo la podríamos haber expresado así: 1) $y-2x=0$, 2) $y-x^2=0$
# , en general en la forma, $F(x,y)=0$. Cuando está dada en esta forma se dice que está en la forma implícita.
#
# > No toda ecuación $F(x,y)=0$ define una función
#
# Notar que en el caso del ejemplo **3)** la ecuación escrita en forma implícita quedaría $y^2-x+1=0$, en este caso dejaría de ser una función ya que debemos considerar ambas ramas de la función raíz cuadrada (Recordar la definición de valor absoluto $|x|=\sqrt{x^2}$).
#
#
# **Raíces de una función**
#
# > Dada un función $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ definida por f(x), los valores de $x$ para los cuales $f(x)=0$ se conocen como las raíces o ceros de la función.
#
# Gráficamente los zeros de la función son los puntos donde la función intersecta el eje de las abscisas (eje de las $x$).
#
# La determinación de las raíces reales de una función, si es que existen, nos permitirán definir los intervalos en los cuales la función es positiva y los intervalos en los cuales es negativa.
#
# **Conjunto de positividad**
#
# > Llamaremos conjunto de positividad de una función al conjunto formado por aquellos valores de x para los cuales $f(x) > 0$.
#
# Notar que el conjunto de positividad de una función está formado por intervalos abiertos y gráficamente son los puntos donde la curva interseca el eje de las $x$s.
#
# **Conjunto de negatividad**
#
# > Llamaremos conjunto de negatividad de una función al conjunto formado por aquellos valores de x para los cuales $f(x) < 0$.
#
# Notar que el conjunto de negatividad de una función está formado por intervalos abiertos y gráficamente son los puntos donde la curva interseca el eje de las $x$s.
#
# $\textbf{Ejemplo 6}$. Sea $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ definida por $f(x)=x^2-4$. Determinar las raíces de la función y los conjuntos de positividad y negatividad. Graficar

# %%
# %matplotlib inline
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5,5, 50)
def cuadratica(a,b,c,x):
    return a*x**2+b*x+c

a=1; b=0; c=-4
#genera el obj figure
plt.figure()
#Eje horizontal
plt.axhline(0, color='black')
#Eje vertical
plt.axvline(0, color='black')
#Grafico la funcion
plt.plot(x,cuadratica(a,b,c,x),'b-',label="$f(x)=x^2-4$")
#Elijo dos puntos
plt.scatter([1,4],[cuadratica(a,b,c,1),cuadratica(a,b,c,4)])
plt.text(1, cuadratica(a,b,c,1)+1,'(1 , %s)'%cuadratica(a,b,c,1),horizontalalignment='center', verticalalignment='center')
plt.text(4, cuadratica(a,b,c,4)+1,'(4 , %s)'%cuadratica(a,b,c,4),horizontalalignment='center', verticalalignment='center')
#Establezco limites para graficar
plt.xlim(-6, 6)
plt.ylim(-5, 16)
#Titulo y nombre a los ejes
plt.title("Ejemplo 6")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Crecimiento y decrecimiento de una función**
#
# Sea $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ :
#
# > Una función se dice **creciente** en un intervalo si para todo par de puntos dentro del intervalo perteneciente al dominio de la función se cumple que si $a < b$  entonces $f(a) < f(b)$
#
# > Una función se dice **decreciente** en un intervalo si para todo par de puntos dentro del intervalo perteneciente al dominio de la función se cumple que si $a < b$  entonces $f(a) > f(b)$.
#
# <center>
# <div style="width: 600px;" >
# <img src="img/cre-decrecimiento.png">
# </center>
# </div>
#
# **Máximos y mínimos de funciones **
#
# Para estudiar lo que ocurre en las cercanías de un dado punto utilizaremos el concepto de *entorno*. Intuitivamente asumiremos que un entorno a un determinado punto consiste en considerar un conjunto de puntos suficientemente cercanos al punto $x=a$ de interés desde ambos lados de la recta real con el objeto que nos permita estudiar el comportamiento de la función.
#
# > Decimos que una función alcanza un **máximo local** o **relativo** en un punto $x=a$ si la imagen de ese punto $f(a)$ es mayor o igual que las imágenes de un entorno suficientemente pequeño de $a$
#
# > Decimos que una función alcanza un **mínimo local** o **relativo** en un punto $x=a$ si la imagen de ese punto $f(a)$ es menor o igual que las imágenes de un entorno suficientemente pequeño de $a$
#
# <center>
# <div style="width: 600px;" >
# <img src="img/maxmin.png">
# </center>
# </div>
#
# A los máximos y mínimos relativos de una función se los llama **extremos relativos**.
# Una función alcanza un **máximo absoluto** en $x = a$ si su imagen $f(a)$ es mayor o igual que las imágenes de todos los demás elementos del dominio. Análogamente el **mínimo absoluto**. El máximo y mínimo absoluto de una función se llaman **extremos absolutos**. Una función puede tener extremos relativos  y no absolutos.
#
# **Simetría de funciones **
#
# Sea $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ :
#
# > Una función $f$ se dice **par**  sii para todo  x$\in Dom(f)$ se cumple que $f(-x)=f(x)$.
#
# > Una función $f$ se dice **impar**  sii para todo  x$\in Dom(f)$ se cumple que $f(-x)=-f(x)$.
#
# Notas:
#
# En la definición está implícito que para que una función sea par o impar una de las condiciones que debe cumplir el $Dom(f)$ es que $\forall x \in Dom(f)$ tamién que todo $-x \in Dom(f)$. Es decir, para que una función sea par o impar es condición necesaria que su dominio sea un conjunto simétrico con respecto al origen.
#
# La gráfica de una función par es simétrica respecto al eje de las ordenadas, mientras que la de una función impar es simétrica respecto al origen de coordenadas.
#
# **Tarea.** Determinar la paridad de las funciones que se muestran a continuación.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5.0, 5.0)

y1 = x**2
y2 = x**3

fig, ax = plt.subplots(1, 2,figsize=(10, 5))
ax[0].plot(x, y1, 'r', lw=3, label="$f(x)=x^2$") #row=0, col=0
ax[1].plot(x, y2, 'g',lw=3,label="$f(x)=x^3$") #row=0, col=1
#Ejes horizontal/vertical
ax[0].axhline(0, color='black')
ax[0].axvline(0, color='black')
ax[1].axhline(0, color='black')
ax[1].axvline(0, color='black')
#Nombre ejes
ax[1].set_xlabel('x')
ax[0].set_ylabel('y')
ax[0].legend(loc='upper center', shadow=True)
ax[1].legend(loc='best', shadow=True)

plt.show()

# %% [markdown]
# <h2>Funciones Algebraicas</h2>
#
# Una función $y=f(x)$ es **algebraica** si, dada la variable independiente $x$, para obtener $f(x)$ deben realizarse sobre la misma un número finito de operaciones algebraicas. Estas operaciones incluyen la suma, resta, multiplicación, división, elevación a potencias enteras o racionales. Un ejemplo de una función algebraica es la función $f$ : $\mathbb{R} \rightarrow \mathbb{R}$ definida por: $f(x)=\frac{(x^2-3x+1)^2}{(5x^{1/2}+x^{1/3})^ {1/5}}$
#
# <h3>Funciones Polinómicas</h3>
#
#
# Dentro de las funciones algebraicas merecen especial atención por su importancia las **funciones polinómicas**
#
# >Una función **polinómica de grado $n$** es una función $P_n$ : $\mathbb{R} \rightarrow \mathbb{R}$ : de la forma:
#
# >$P_n(x)=a_nx^n+a_{n-1}x^{n-1}+...+a_1x+a_0$
#
# >donde $n$ es un entero no negativo y $a_n\neq0$
#
# Los números $a_0, a_1, a_2, ..., a_n$ se denomninan **coeficientes** del polinomio.
#
# El número $a_0$ es el coeficiene constante o término constante.
#
# El número $a_n$, el coeficiene que acompaña la potencia más alta, es el coeficiente dominante y el término $a_nx^n$ se denomina término dominante.
#
# El $Dom(P_n) = \mathbb{R}$ cualquiera sea $n$.
#
# Observaciones:
#
# * Si la función polinómica es de grado 1, obtenemos la función lineal, que discutimos más arriba.
#
# * Si la función polinómica es de grado 0 obtenemos una función denominada constante
#
# * Los polinomios con un término se llaman monomios.
#
#
# $\textbf{Ejemplo 7}$. Dentro de las funciones polinómicas ocupan un lugar destacado las de la forma $f(x)=x^n$, $n\in \mathbb{N}$, graficar.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5.0, 5.0)
fig, ax = plt.subplots(nrows=2, ncols=3)

i = 0
for row in ax:
    for col in row:
        col.plot(x, [x**i for x in x ],lw=2,c='red',label="$f(x)=x^%s$"%i)
        col.legend(loc='best', shadow=True)
        col.axhline(0, color='black')
        col.axvline(0, color='black')
        col.set_xlabel('x')
        col.set_ylabel('y')
        col.set_xlim(-6.,6.)
        col.set_ylim(-10.,10.)
        i=i+1
 

plt.show()

# %% [markdown]
# <h2>Material adicional</h2>
#
# $\textbf{Ejemplo 8.}$ Dar una expresión analítica para la siguiente función y determinar el dominio: Un rectángulo tiene un área de 10cm$²$, expresar el perímetro en función de la lonigtud de uno de sus lados.
#
# Sean $x$ e $y$ las longitudes de los lados del rectángulo.
#
# $A$ = $xy$ (área del rectángulo)
#
#  $xy=10\,cm^2$ (1)
#
#  Como el área es distanta de cero, tenemos que $x \neq 0$ e $y\neq 0$.
#
#  Por definición de de perímetro: $P(x,y)=2x+2y$ (2)
#
#  por (1) y como $x\neq 0$ tenems que $y=10/x$ que reemplazando en (2) queda
#
#  $P(x)=2(x+\frac{10cm^2}{x})=\frac{2x^2+20cm^2}{x}$ (3)
#
#  El dominio de (3) es $Dom(P)=\{x/x>0\}$, por lo que $x$ no puede ser menor que cero pues x representa la longitud de un lado del rectángulo.
#
#  Notar que el $Dom(P)$ no depende solamente de la fórmula (3) sino también del significado que tiene la variable $x$.

# %%
# %matplotlib inline
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1e-10,6, 50)
def perimetro(x):
    return (2*x**2+20)/x

#genera el obj figure
plt.figure()
#Eje horizontal
plt.axhline(0, color='black')
#Eje vertical
plt.axvline(0, color='black')
#Grafico la funcion
plt.plot(x,perimetro(x),'g-',lw=2,label="Perímetro del rectángulo")
#Establezco limites para graficar
plt.xlim(0., 6.)
plt.ylim(0., 50)
#Titulo y nombre a los ejes
plt.title("Ejemplo 8")
plt.xlabel("Longitud de uno de los lados (cm)")
plt.ylabel("Perímetro (cm)")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# <h3>Referencias</h3>
#
# [1] Stewart, James. Single variable calculus: Early transcendentals. Cengage Learning, 2015.
#
# [2] Armando, Rojo. "Algebra I." Edición XX. Editorial El Ateneo (2001).
#
# [3] Diapositivas de clase elaboradas por la Dra. Mónica de Torres de Curth  para la cátedra de Matemáticas I de la Licenciatura y Profesorado en Biología de la Universidad del Comahue. Centro Regional Bariloche
